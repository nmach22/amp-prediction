# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/processed/embeddings/data_for_classification.csv')

# %%
data.head()
# Out:
#        sequence                            species         mic  active
# 0        LFIFFF              Staphylococcus aureus   15.000000     1.0
# 1        LFIFFF            Streptococcus sanguinis    5.000000     1.0
# 2  KVvvKWVvKvVK   Staphylococcus aureus ATCC 6538P  218.102267     0.0
# 3  KVvvKWVvKvVK        Bacillus subtilis ATCC 6051  218.102267     0.0
# 4  KVvvKWVvKvVK  Pseudomonas aeruginosa ATCC 27853  218.102267     0.0

# %%
data.shape
# Out:
# (115078, 4)

# %%
len(data['sequence'].unique())
# Out:
# 16401

# %%
(data['active'] == 1 ).sum()
# Out:
# np.int64(50341)

# %%
(data['active'] == 0 ).sum()
# Out:
# np.int64(64689)
