# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('../data/processed/embeddings/sequences_with_MIC.csv')

# %%
data.head()
# Out:
#        sequence                            species         mic reference
# 0        LFIFFF              Staphylococcus aureus   15.000000         1
# 1        LFIFFF            Streptococcus sanguinis    5.000000         1
# 2  KVvvKWVvKvVK   Staphylococcus aureus ATCC 6538P  218.102267         1
# 3  KVvvKWVvKvVK        Bacillus subtilis ATCC 6051  218.102267         1
# 4  KVvvKWVvKvVK  Pseudomonas aeruginosa ATCC 27853  218.102267         1

# %%
data.shape
# Out:
# (115078, 4)

# %%
data['reference'].unique()
# Out:
# <StringArray>
# [                '1',                 '3',                 '4',
#                  '2',                 '5',                 '8',
#                  '9',                '10',                '11',
#                 '12',                '13',                 '6',
#               '4, 5',                 '7',           '2, 3, 8',
#               '2, 3',              '1, 3',              '6, 7',
#               '1, 2',                '15',                '16',
#                 '18',                '19',                '20',
#             '11, 12',                '14',              '3, 4',
#              '1, 21',              '3, 9',                '17',
#                 '21',                '23',             '6, 14',
#               '4, 7',              '1, 5',              '2, 6',
#              '8, 22',                '22',            '22, 27',
#                 '24',                '25',                '26',
# ...

# %%
(data['reference'] == 2 ).sum()
# Out:
# np.int64(0)
