# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the dataset
data = pd.read_csv('../data/raw/dbaasp_full.csv')

# %%
data.head(10)
# Out:
#    peptide_id peptide_name      sequence  \
# 0          13         RNal        RRXXRF
# 1          13         RNal        RRXXRF
# 2           8          NaN  KVvvKWVvKvVK
# 3           8          NaN  KVvvKWVvKvVK
# 4           8          NaN  KVvvKWVvKvVK
# 5           8          NaN  KVvvKWVvKvVK
# 6           8          NaN  KVvvKWVvKvVK
# 7           8          NaN  KVvvKWVvKvVK
# 8           8          NaN  KVvvKWVvKvVK
# 9           8          NaN  KVvvKWVvKvVK
#
#                          target_species activity_measure  activity_value  \
# 0                Bacillus subtilis PY22              MIC        4.277080
# 1             Escherichia coli DH5alpha              MIC       17.108320
# 2      Staphylococcus aureus ATCC 6538P              MIC      165.228990
# 3           Bacillus subtilis ATCC 6051              MIC      165.228990
# 4     Pseudomonas aeruginosa ATCC 27853              MIC      165.228990
# ...

# %%
data.shape
# Out:
# (162700, 10)
